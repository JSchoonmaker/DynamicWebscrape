# %% [markdown]
# # Webscraping dynamic page content

# %% [markdown]
# ### My husband mentioned needing to get information from ASQ about newly certified members. ASQ's site provides some search options, but not as specific as he needed, and he would've needed to copy/paste dozens of pages of search results into a spreadsheet in order to further filter responses. I offered to find a webscraping option for him. My thanks to Damien Martin and this helpful post: https://kiwidamien.github.io/using-api-calls-via-the-network-panel.html for instructions about determining the correct url to access search results.
#
# ### Takeaways from this:
#
# ## 1. In previous projects, I had struggled with how to webscrape pages that required user input (search fields, buttons, etc.). This gave me a great opportunity to learn something new and use it in a way that helped save time and effort and decrease manual input.
#
# ## 2.  Ultimately, I found similar functionality through Excel, which is more widely used by my husband's team, and thus easier for them to incorporate, so this process won't be implemented for now.
#
# ## 3. There will often be multiple options for achieving results. Determining which one best fits a team's skills and needs (as opposed to just using the one I think is cooler 😎) is a critical step.
#
# ## 4. This was a quick project I did while in the middle of a larger data science project. I hesitated to share it at first, because it only took me a few hours and didn't seem impactful enough to be worthwhile, but EVERY project has the potential to both increase my knowledge and experience as well as possibly being helpful to others.

# %%
import json
import requests
import pandas as pd

# %%
url = 'https://asq.org/cert/asq/VerificationPager.aspx?page=0&size=2000&Certification=&Country=US&State=IA&Province=&Name='

# Make the same request that Javascript makes
r = requests.get(url)

# %%
#Verifying the correct info was collected
print(r.text)
# Out:
# [1606,[["9601", "Abele, Grant D.", "Garner, IA", "UNITED STATES", "CQI", "March, 2000", "Active"],["516", "Abele, Grant D.", "Garner, IA", "UNITED STATES", "CQIA", "June, 2001", "Active"],["20318", "Abodeely, Paul D.", "Lisbon, IA", "UNITED STATES", "CQT", "March, 2007", "Active"],["7036", "Adams, David A.", "Marion, IA", "UNITED STATES", "CQT", "March, 1992", "Active"],["3529", "Adrian, Edwin M.", "West Union, IA", "UNITED STATES", "CQI", "March, 1992", "Active"],["21845", "Agarwal, Nikhil", "Davenport, IA", "UNITED STATES", "CQT", "October, 2010", "Active"],["2448", "Ahmed, Ovais", "Bettendorf, IA", "UNITED STATES", "CSSBB", "October, 2004", "Active"],["15906", "Ahmed, Ovais", "Bettendorf, IA", "UNITED STATES", "CQA", "December, 1996", "Active"],["36869", "Ahmed, Ovais", "Bettendorf, IA", "UNITED STATES", "CQE", "June, 1997", "Active"],["98838", "Alagappan Thangavel, Saravanan", "Coralville, IA", "UNITED STATES", "CQE", "June, 2016", "Active"],["65338", "Alagappan Thangavel, Saravanan", "Coralville, IA", "UNITED STATES", "CQA", "May, 2016", "Active"],["54359", "Alagappan Thangavel, Saravanan", "Coralville, IA", "UNITED STATES", "CMQ/OE", "January, 2017", "Active"],["17755", "Alagappan Thangavel, Saravanan", "Coralville, IA", "UNITED STATES", "CSSGB", "October, 2017", "Active"],["15212", "Albers, Laurie A.", "Clarion, IA", "UNITED STATES", "CQT", "October, 1999", "Active"],["11153", "Albert, Richard D.", "Eldon, IA", "UNITED STATES", "CQT", "March, 1996", "Active"],["44523", "Albert, Richard D.", "Eldon, IA", "UNITED STATES", "CQE", "December, 2002", "Active"],["11184", "Alcorn, Larry W.", "Winterset, IA", "UNITED STATES", "CQT", "March, 1996", "Active"],["3531", "Allen, Charles J.", "Danville, IA", "UNITED STATES", "CQI", "March, 1992", "Active"],["57975", "Allen, Matthew D.", "Solon, IA", "UNITED STATES", "CQE", "December, 2011", "Active"],["14670", "Allen, Matthew D.", "Solon, IA", "UNITED STATES", "CMQ/OE", "April, 2011", "Active"],["41285", "Allen, Matthew D.", "Solon, IA", "UNITED STATES", "CQA", "December, 2010", "Active"],["7359", "Allen, Matthew D.", "Solon, IA", "UNITED STATES", "CRE", "October, 2011", "Active"],["5745", "Allen, Matthew D.", "Solon, IA", "UNITED STATES", "CSSGB", "June, 2011", "Active"],["24505", "Allen, Thomas E.", "Missouri Valley, IA", "UNITED STATES", "CQT", "March, 2016", "Active"],["16227", "Allen, Tracy L.", "Hornick, IA", "UNITED STATES", "CQT", "October, 2000", "Active"],["7041", "Allison, Carol A.", "Waterloo, IA", "UNITED STATES", "CQT", "March, 1992", "Active"],["20223", "Allman, Allyson", "North Liberty, IA", "UNITED STATES", "CSSGB", "June, 2019", "Active"],["15001", "Almon, Guy W.", "Pella, IA", "UNITED STATES", "CQT", "October, 1999", "Active"],["12345", "Anderberg, Jay S.", "Webster City, IA", "UNITED STATES", "CQT", "October, 1996", "Active"],["2787", "Anderson, Collin W.", "Cedar Falls, IA", "UNITED STATES", "CSSGB", "June, 2009", "Active"],["22240", "Anderson, Curtis A.", "Spencer, IA", "UNITED STATES", "CQT", "March, 2012", "Active"],["12315", "Anderson, Ed R.", "Webster City, IA", "UNITED STATES", "CQT", "October, 1996", "Active"],["48602", "Anderson, Jay C", "Council Bluffs, IA", "UNITED STATES", "CQA", "December, 2014", "Active"],["23234", "Anderson, Jay C", "Council Bluffs, IA", "UNITED STATES", "CQT", "March, 2014", "Active"],["15929", "Anderson, Michael A.", "Ames, IA", "UNITED STATES", "CQT", "March, 2000", "Active"],["22994", "Anderson, Scott A.", "Spencer, IA", "UNITED STATES", "CQT", "October, 2013", "Active"],["8836", "Anderson, Vicki L.", "Sheffield, IA", "UNITED STATES", "CQT", "October, 1993", "Active"],["11653", "Andreasen, Deanna L.", "Forest City, IA", "UNITED STATES", "CQT", "March, 1996", "Active"],["12595", "Andrews, Kyle", "Cedar Rapids, IA", "UNITED STATES", "CSSGB", "December, 2014", "Active"],["4928", "Angstrom, Charles A.", "Fort Dodge, IA", "UNITED STATES", "CQI", "March, 1994", "Active"],["2247", "Anschutz, Wayne F.", "Pella, IA", "UNITED STATES", "CMQ ...

# %%
#Organizing and formatting the information so it can be put in a dataframe and saved as .csv file
certs = []
certs.extend(r.json())

# %%
#View the information so I can correctly assign dataframe column names
certs[1]
# Out:
# [['9601',
#   'Abele, Grant D.',
#   'Garner, IA',
#   'UNITED STATES',
#   'CQI',
#   'March, 2000',
#   'Active'],
#  ['516',
#   'Abele, Grant D.',
#   'Garner, IA',
#   'UNITED STATES',
#   'CQIA',
#   'June, 2001',
#   'Active'],
#  ['20318',
#   'Abodeely, Paul D.',
#   'Lisbon, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2007',
#   'Active'],
#  ['7036',
#   'Adams, David A.',
#   'Marion, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1992',
#   'Active'],
#  ['3529',
#   'Adrian, Edwin M.',
#   'West Union, IA',
#   'UNITED STATES',
#   'CQI',
#   'March, 1992',
#   'Active'],
#  ['21845',
#   'Agarwal, Nikhil',
#   'Davenport, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 2010',
#   'Active'],
#  ['2448',
#   'Ahmed, Ovais',
#   'Bettendorf, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'October, 2004',
#   'Active'],
#  ['15906',
#   'Ahmed, Ovais',
#   'Bettendorf, IA',
#   'UNITED STATES',
#   'CQA',
#   'December, 1996',
#   'Active'],
#  ['36869',
#   'Ahmed, Ovais',
#   'Bettendorf, IA',
#   'UNITED STATES',
#   'CQE',
#   'June, 1997',
#   'Active'],
#  ['98838',
#   'Alagappan Thangavel, Saravanan',
#   'Coralville, IA',
#   'UNITED STATES',
#   'CQE',
#   'June, 2016',
#   'Active'],
#  ['65338',
#   'Alagappan Thangavel, Saravanan',
#   'Coralville, IA',
#   'UNITED STATES',
#   'CQA',
#   'May, 2016',
#   'Active'],
#  ['54359',
#   'Alagappan Thangavel, Saravanan',
#   'Coralville, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'January, 2017',
#   'Active'],
#  ['17755',
#   'Alagappan Thangavel, Saravanan',
#   'Coralville, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'October, 2017',
#   'Active'],
#  ['15212',
#   'Albers, Laurie A.',
#   'Clarion, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 1999',
#   'Active'],
#  ['11153',
#   'Albert, Richard D.',
#   'Eldon, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1996',
#   'Active'],
#  ['44523',
#   'Albert, Richard D.',
#   'Eldon, IA',
#   'UNITED STATES',
#   'CQE',
#   'December, 2002',
#   'Active'],
#  ['11184',
#   'Alcorn, Larry W.',
#   'Winterset, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1996',
#   'Active'],
#  ['3531',
#   'Allen, Charles J.',
#   'Danville, IA',
#   'UNITED STATES',
#   'CQI',
#   'March, 1992',
#   'Active'],
#  ['57975',
#   'Allen, Matthew D.',
#   'Solon, IA',
#   'UNITED STATES',
#   'CQE',
#   'December, 2011',
#   'Active'],
#  ['14670',
#   'Allen, Matthew D.',
#   'Solon, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'April, 2011',
#   'Active'],
#  ['41285',
#   'Allen, Matthew D.',
#   'Solon, IA',
#   'UNITED STATES',
#   'CQA',
#   'December, 2010',
#   'Active'],
#  ['7359',
#   'Allen, Matthew D.',
#   'Solon, IA',
#   'UNITED STATES',
#   'CRE',
#   'October, 2011',
#   'Active'],
#  ['5745',
#   'Allen, Matthew D.',
#   'Solon, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2011',
#   'Active'],
#  ['24505',
#   'Allen, Thomas E.',
#   'Missouri Valley, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2016',
#   'Active'],
#  ['16227',
#   'Allen, Tracy L.',
#   'Hornick, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 2000',
#   'Active'],
#  ['7041',
#   'Allison, Carol A.',
#   'Waterloo, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1992',
#   'Active'],
#  ['20223',
#   'Allman, Allyson',
#   'North Liberty, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2019',
#   'Active'],
#  ['15001',
#   'Almon, Guy W.',
#   'Pella, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 1999',
#   'Active'],
#  ['12345',
#   'Anderberg, Jay S.',
#   'Webster City, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 1996',
#   'Active'],
#  ['2787',
#   'Anderson, Collin W.',
#   'Cedar Falls, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2009',
#   'Active'],
#  ['22240',
#   'Anderson, Curtis A.',
#   'Spencer, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2012',
#   'Active'],
#  ['12315',
#   'Anderson, Ed R.',
#   'Webster City, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 1996',
#   'Active'],
#  ['48602',
#   'Anderson, Jay C',
#   'Council Bluffs, IA',
#   'UNITED STATES',
#   'CQA',
#   'December, 2014',
#   'Active'],
#  ['23234',
#   'Anderson, Jay C',
#   'Council Bluffs, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2014',
#   'Active'],
#  ['15929',
#   'Anderson, Michael A.',
#   'Ames, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2000',
#   'Active'],
#  ['22994',
#   'Anderson, Scott A.',
#   'Spencer, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 2013',
#   'Active'],
#  ['8836',
#   'Anderson, Vicki L.',
#   'Sheffield, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 1993',
#   'Active'],
#  ['11653',
#   'Andreasen, Deanna L.',
#   'Forest City, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1996',
#   'Active'],
#  ['12595',
#   'Andrews, Kyle',
#   'Cedar Rapids, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'December, 2014',
#   'Active'],
#  ['4928',
#   'Angstrom, Charles A.',
#   'Fort Dodge, IA',
#   'UNITED STATES',
#   'CQI',
#   'March, 1994',
#   'Active'],
#  ['2247',
#   'Anschutz, Wayne F.',
#   'Pella, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'March, 1997',
#   'Active'],
#  ['34566',
#   'Anschutz, Wayne F.',
#   'Pella, IA',
#   'UNITED STATES',
#   'CQE',
#   'December, 1995',
#   'Active'],
#  ['12330',
#   'Anschutz, Wayne F.',
#   'Pella, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'March, 2012',
#   'Active'],
#  ['6277',
#   'Apte, Kaustabh',
#   'Urbandale, IA',
#   'UNITED STATES',
#   'CSQE',
#   'October, 2017',
#   'Active'],
#  ['82',
#   'Arkema, Mark A.',
#   'Pella, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'October, 2001',
#   'Active'],
#  ['15052',
#   'Arkema, Mark A.',
#   'Pella, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'October, 2011',
#   'Active'],
#  ['39701',
#   'Arkema, Mark A.',
#   'Pella, IA',
#   'UNITED STATES',
#   'CQA',
#   'November, 2009',
#   'Active'],
#  ['8802',
#   'Arling, Joseph M.',
#   'Des Moines, IA',
#   'UNITED STATES',
#   'CQIA',
#   'June, 2012',
#   'Active'],
#  ['8556',
#   'Armstrong, Gregory J.',
#   'Red Oak, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 1993',
#   'Active'],
#  ['3535',
#   'Armstrong, Scott A.',
#   'Robins, IA',
#   'UNITED STATES',
#   'CQI',
#   'March, 1992',
#   'Active'],
#  ['75449',
#   'Arnone, Laura A.',
#   'Davenport, IA',
#   'UNITED STATES',
#   'CQI',
#   'February, 2019',
#   'Active'],
#  ['64334',
#   'Arnone, Laura A.',
#   'Davenport, IA',
#   'UNITED STATES',
#   'CQA',
#   'July, 2015',
#   'Active'],
#  ['5934',
#   'Aschbrenner, Randy G',
#   'Cedar Rapids, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'March, 2001',
#   'Active'],
#  ['41356',
#   'Aschbrenner, Randy G',
#   'Cedar Rapids, IA',
#   'UNITED STATES',
#   'CQE',
#   'December, 2000',
#   'Active'],
#  ['12554',
#   'Ash, Thom',
#   'Cedar Rapids, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'December, 2014',
#   'Active'],
#  ['635',
#   'Awtry, Bill J.',
#   'Garner, IA',
#   'UNITED STATES',
#   'CQIA',
#   'June, 2001',
#   'Active'],
#  ['21849',
#   'Axinte-Hendrickson, Costica',
#   'Waterloo, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 2010',
#   'Active'],
#  ['11700',
#   'Babe, Bob',
#   'Sac City, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2014',
#   'Active'],
#  ['9298',
#   'Bahulekar, Sumukh V.',
#   'Bettendorf, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2013',
#   'Active'],
#  ['51014',
#   'Bahulekar, Sumukh V.',
#   'Bettendorf, IA',
#   'UNITED STATES',
#   'CQE',
#   'June, 2007',
#   'Active'],
#  ['15622',
#   'Bahulekar, Sumukh V.',
#   'Bettendorf, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'October, 2012',
#   'Active'],
#  ['45263',
#   'Bahulekar, Sumukh V.',
#   'Bettendorf, IA',
#   'UNITED STATES',
#   'CQA',
#   'May, 2013',
#   'Active'],
#  ['20586',
#   'Bailey, Bruce O.',
#   'Clear Lake, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 2007',
#   'Active'],
#  ['11236',
#   'Bair, Darwin T.',
#   'Altoona, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1996',
#   'Active'],
#  ['31393',
#   'Baird, Denise A.',
#   'West Liberty, IA',
#   'UNITED STATES',
#   'CQA',
#   'December, 2004',
#   'Active'],
#  ['781',
#   'Baker, Tammy R.',
#   'North Liberty, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2007',
#   'Active'],
#  ['5762',
#   'Baker, Todd',
#   'Coralville, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2011',
#   'Active'],
#  ['14331',
#   'Baldwin, Ariel',
#   'Shenandoah, IA',
#   'UNITED STATES',
#   'CQIA',
#   'August, 2019',
#   'Active'],
#  ['9884',
#   'Baldwin, Steven E.',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CQIA',
#   'December, 2013',
#   'Active'],
#  ['19472',
#   'Ball, Lonnie D',
#   'Pella, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 2005',
#   'Active'],
#  ['14190',
#   'Ball, Michael',
#   'Urbandale, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'December, 2015',
#   'Active'],
#  ['11460',
#   'Bandstra, Karen A.',
#   'Pella, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1996',
#   'Active'],
#  ['8231',
#   'Bandstra, Karen A.',
#   'Pella, IA',
#   'UNITED STATES',
#   'CQI',
#   'March, 1998',
#   'Active'],
#  ['10981',
#   'Banes, Tracy L.',
#   'Millersburg, IA',
#   'UNITED STATES',
#   'CQI',
#   'March, 2002',
#   'Active'],
#  ['10660',
#   'Bantz, Larry R.',
#   'Waterloo, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1995',
#   'Active'],
#  ['1101',
#   'Barber, Billie L.',
#   'Eldora, IA',
#   'UNITED STATES',
#   'CQI',
#   'April, 1987',
#   'Active'],
#  ['3076',
#   'Barnhart, Kathy M.',
#   'Iowa City, IA',
#   'UNITED STATES',
#   'CQIA',
#   'December, 2004',
#   'Active'],
#  ['9407',
#   'Barrick, Geoffrey W.',
#   'Marengo, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1999',
#   'Active'],
#  ['18303',
#   'Barrick, Geoffrey W.',
#   'Marengo, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 2003',
#   'Active'],
#  ['1597',
#   'Barthiban, Pratheen',
#   'Cedar Falls, IA',
#   'UNITED STATES',
#   'CSSYB',
#   'March, 2019',
#   'Active'],
#  ['2755',
#   'Bartholmy, David W.',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'May, 2009',
#   'Active'],
#  ['7',
#   'Basala, Joseph T.',
#   'Bettendorf, IA',
#   'UNITED STATES',
#   'MBB',
#   'August, 2010',
#   'Active'],
#  ['3087',
#   'Basala, Joseph T.',
#   'Bettendorf, IA',
#   'UNITED STATES',
#   'CQA',
#   'June, 1992',
#   'Active'],
#  ['1385',
#   'Basala, Joseph T.',
#   'Bettendorf, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'March, 1996',
#   'Active'],
#  ['24165',
#   'Basala, Joseph T.',
#   'Bettendorf, IA',
#   'UNITED STATES',
#   'CQE',
#   'June, 1991',
#   'Active'],
#  ['84',
#   'Basala, Joseph T.',
#   'Bettendorf, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'October, 2001',
#   'Active'],
#  ['3869',
#   'Basala, Joseph T.',
#   'Bettendorf, IA',
#   'UNITED STATES',
#   'CRE',
#   'October, 1994',
#   'Active'],
#  ['1356',
#   'Bates III, Floyd D.',
#   'Urbandale, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'October, 2003',
#   'Active'],
#  ['11070',
#   'Bates III, Floyd D.',
#   'Urbandale, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'October, 2007',
#   'Active'],
#  ['30492',
#   'Bates III, Floyd D.',
#   'Urbandale, IA',
#   'UNITED STATES',
#   'CQA',
#   'June, 2004',
#   'Active'],
#  ['2462',
#   'Bates III, Floyd D.',
#   'Urbandale, IA',
#   'UNITED STATES',
#   'CSQE',
#   'December, 2003',
#   'Active'],
#  ['921',
#   'Bauer, Matthew',
#   'Iowa City, IA',
#   'UNITED STATES',
#   'CSSYB',
#   'January, 2018',
#   'Active'],
#  ['9073',
#   'Baylor, Thomas G.',
#   'Grinnell, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1994',
#   'Active'],
#  ['4052',
#   'Baylor, Tim G.',
#   'Red Oak, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1992',
#   'Active'],
#  ['3232',
#   'Bean, James Joseph',
#   'Marion, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1991',
#   'Active'],
#  ['11238',
#   'Beaver, Randy M.',
#   'Mason City, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1996',
#   'Active'],
#  ['14251',
#   'Beavers, Nate',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'December, 2015',
#   'Active'],
#  ['170',
#   'Beck, Joshua',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CSSYB',
#   'October, 2015',
#   'Active'],
#  ['11090',
#   'Beck, Joshua',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CQIA',
#   'June, 2015',
#   'Active'],
#  ['4209',
#   'Becker, Michael T.',
#   'Cedar Rapids, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'March, 2006',
#   'Active'],
#  ['46100',
#   'Becker, Michael T.',
#   'Cedar Rapids, IA',
#   'UNITED STATES',
#   'CQE',
#   'June, 2004',
#   'Active'],
#  ['12571',
#   'Becker, Robert J.',
#   'Jefferson, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1997',
#   'Active'],
#  ['18867',
#   'Beebe, Lisa Kay',
#   'Oskaloosa, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 2004',
#   'Active'],
#  ['50433',
#   'Beke, Michael A.',
#   'Cedar Rapids, IA',
#   'UNITED STATES',
#   'CQE',
#   'December, 2006',
#   'Active'],
#  ['19194',
#   'Bender, Candis J.',
#   'Pella, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2005',
#   'Active'],
#  ['30665',
#   'Benes, Bryan J.',
#   'Indianola, IA',
#   'UNITED STATES',
#   'CQE',
#   'December, 1993',
#   'Active'],
#  ['20609',
#   'Benes, Bryan J.',
#   'Indianola, IA',
#   'UNITED STATES',
#   'CQA',
#   'June, 1999',
#   'Active'],
#  ['3660',
#   'Benes, Bryan J.',
#   'Indianola, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'October, 1998',
#   'Active'],
#  ['2472',
#   'Benes, Bryan J.',
#   'Indianola, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'October, 2004',
#   'Active'],
#  ['23244',
#   'Benetti, Marco',
#   'Adel, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2014',
#   'Active'],
#  ['18868',
#   'Benjamin, Willis W.',
#   'Pella, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 2004',
#   'Active'],
#  ['9540',
#   'Bennett, Mark B.',
#   'Mason City, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1994',
#   'Active'],
#  ['11711',
#   'Bennett, Troy Del',
#   'Pella, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1996',
#   'Active'],
#  ['5262',
#   'Benson, Della R.',
#   'Lake Mills, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1990',
#   'Active'],
#  ['11625',
#   'Benson, Janice',
#   'Cedar Falls, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1996',
#   'Active'],
#  ['7809',
#   'Berger, Anthony P.',
#   'Williamsburg, IA',
#   'UNITED STATES',
#   'CQI',
#   'March, 1997',
#   'Active'],
#  ['99908',
#   'Bianchi, Anthony',
#   'Cedar Falls, IA',
#   'UNITED STATES',
#   'CQE',
#   'December, 2016',
#   'Active'],
#  ['12559',
#   'Bianchi, Anthony',
#   'Cedar Falls, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'December, 2014',
#   'Active'],
#  ['13485',
#   'Bibens, Seth A.',
#   'Eldridge, IA',
#   'UNITED STATES',
#   'CQIA',
#   'August, 2018',
#   'Active'],
#  ['25830',
#   'Biedenharn, Jessica',
#   'Clinton, IA',
#   'UNITED STATES',
#   'CQT',
#   'September, 2019',
#   'Active'],
#  ['2562',
#   'Billings, Garon K.',
#   'Davenport, IA',
#   'UNITED STATES',
#   'CQIA',
#   'June, 2004',
#   'Active'],
#  ['16182',
#   'Bills, Robert C.',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'March, 2015',
#   'Active'],
#  ['59758',
#   'Bills, Robert C.',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CQE',
#   'December, 2012',
#   'Active'],
#  ['54946',
#   'Bingaman, Bridget',
#   'Norwalk, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'January, 2018',
#   'Active'],
#  ['10222',
#   'Blair-Broeker, Eric',
#   'Waterloo, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'December, 2013',
#   'Active'],
#  ['5270',
#   'Blanchard, Carol A.',
#   'Denver, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1990',
#   'Active'],
#  ['10490',
#   'Blay, Bruce C.',
#   'Red Oak, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1995',
#   'Active'],
#  ['10160',
#   'Blay, Bruce C.',
#   'Red Oak, IA',
#   'UNITED STATES',
#   'CQI',
#   'March, 2001',
#   'Active'],
#  ['68453',
#   'Blosse, Pierre',
#   'Des Moines, IA',
#   'UNITED STATES',
#   'CQA',
#   'April, 2018',
#   'Active'],
#  ['179',
#   'Bobier, Lori A.',
#   'Sioux City, IA',
#   'UNITED STATES',
#   'CQIA',
#   'January, 2001',
#   'Active'],
#  ['4834',
#   'Bock, Steven W.',
#   'West Des Moines, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 1989',
#   'Active'],
#  ['10638',
#   'Boddicker, Rosina T.',
#   'Long Grove, IA',
#   'UNITED STATES',
#   'CQIA',
#   'December, 2014',
#   'Active'],
#  ['1457',
#   'Boeding, Russ',
#   'Waterloo, IA',
#   'UNITED STATES',
#   'CQPA',
#   'June, 2013',
#   'Active'],
#  ['21733',
#   'Boelman, Valerie M.',
#   'West Des Moines, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'January, 2020',
#   'Active'],
#  ['9336',
#   'Boelman, Valerie M.',
#   'West Des Moines, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2013',
#   'Active'],
#  ['20549',
#   'Boertje, Bruce',
#   'Pella, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2007',
#   'Active'],
#  ['42089',
#   'Boesenberg, Kelly A',
#   'Ames, IA',
#   'UNITED STATES',
#   'CQA',
#   'June, 2011',
#   'Active'],
#  ['53833',
#   'Boesenberg, Kelly A',
#   'Ames, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'May, 2016',
#   'Active'],
#  ['8243',
#   'Bolar, Steven M.',
#   'Marshalltown, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1993',
#   'Active'],
#  ['3993',
#   'Bolar, Steven M.',
#   'Marshalltown, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1992',
#   'Active'],
#  ['10994',
#   'Bonnichsen, William C.',
#   'Marengo, IA',
#   'UNITED STATES',
#   'CQI',
#   'March, 2002',
#   'Active'],
#  ['21640',
#   'Bono, Richard W',
#   'Bloomfield, IA',
#   'UNITED STATES',
#   'CQE',
#   'June, 1990',
#   'Active'],
#  ['1371',
#   'Bono, Richard W',
#   'Bloomfield, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'October, 2003',
#   'Active'],
#  ['10340',
#   'Booth, David J.',
#   'Coralville, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1995',
#   'Active'],
#  ['11657',
#   'Boothroyd, Mary Lou',
#   'Britt, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1996',
#   'Active'],
#  ['55612',
#   'Borel, Dawn',
#   'Clear Lake, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'January, 2019',
#   'Active'],
#  ['942',
#   'Bormann-Rochotte, Lynn M',
#   'Fairfield, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'March, 2003',
#   'Active'],
#  ['25302',
#   'Bower, Timothy W.',
#   'Fairfield, IA',
#   'UNITED STATES',
#   'CQE',
#   'December, 1991',
#   'Active'],
#  ['8887',
#   'Bowley, Charles F.',
#   'Red Oak, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 1993',
#   'Active'],
#  ['75451',
#   'Boyles, Robert A.',
#   'Bettendorf, IA',
#   'UNITED STATES',
#   'CQI',
#   'February, 2019',
#   'Active'],
#  ['1855',
#   'Brace, Nathan',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CQPA',
#   'June, 2014',
#   'Active'],
#  ['9906',
#   'Brace, Nathan',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CQIA',
#   'December, 2013',
#   'Active'],
#  ['1668',
#   'Bradshaw, Stephen W.',
#   'Des Moines, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1988',
#   'Active'],
#  ['4375',
#   'Bradshaw, Stephen W.',
#   'Des Moines, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1989',
#   'Active'],
#  ['50454',
#   'Brady, Thomas L.',
#   'Iowa City, IA',
#   'UNITED STATES',
#   'CQE',
#   'December, 2006',
#   'Active'],
#  ['24231',
#   'Bragg, Jeff S.',
#   'Pella, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 2015',
#   'Active'],
#  ['99502',
#   'Brand, Amy',
#   'Muscatine, IA',
#   'UNITED STATES',
#   'CQE',
#   'December, 2016',
#   'Active'],
#  ['14193',
#   'Braun, Kevin G.',
#   'Peosta, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'October, 2013',
#   'Active'],
#  ['1073',
#   'Brechlin, Dean J.',
#   'Burlington, IA',
#   'UNITED STATES',
#   'CQPA',
#   'December, 2011',
#   'Active'],
#  ['21955',
#   'Brechlin, Dean J.',
#   'Burlington, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2011',
#   'Active'],
#  ['13570',
#   'Brechlin, Dean J.',
#   'Burlington, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 2011',
#   'Active'],
#  ['5813',
#   'Brechlin, Dean J.',
#   'Burlington, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2011',
#   'Active'],
#  ['58968',
#   'Breid, Daren',
#   'Waterloo, IA',
#   'UNITED STATES',
#   'CQE',
#   'June, 2012',
#   'Active'],
#  ['5551',
#   'Brennan, Terry D.',
#   'Fort Dodge, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1994',
#   'Active'],
#  ['11875',
#   'Briese, Reinette I.',
#   'Belle Plaine, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 2004',
#   'Active'],
#  ['6703',
#   'Brinker, Kevin J.',
#   'West Des Moines, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 1991',
#   'Active'],
#  ['40498',
#   'Britten, Eleanor S.',
#   'Ames, IA',
#   'UNITED STATES',
#   'CQA',
#   'May, 2010',
#   'Active'],
#  ['28702',
#   'Broderick, Jerold E.',
#   'Maurice, IA',
#   'UNITED STATES',
#   'CQA',
#   'December, 2002',
#   'Active'],
#  ['208',
#   'Broderick, Jerold E.',
#   'Maurice, IA',
#   'UNITED STATES',
#   'CFSQA',
#   'March, 2004',
#   'Active'],
#  ['23016',
#   'Brown, Clinton M.',
#   'De Soto, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 2013',
#   'Active'],
#  ['18321',
#   'Brown, Cory Edmund',
#   'Pella, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 2003',
#   'Active'],
#  ['8821',
#   'Brown, Mark James',
#   'Storm Lake, IA',
#   'UNITED STATES',
#   'CQIA',
#   'June, 2012',
#   'Active'],
#  ['3901',
#   'Brown, Penny Ann',
#   'Washington, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1992',
#   'Active'],
#  ['11656',
#   'Brownlee III, Travis',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CQIA',
#   'December, 2015',
#   'Active'],
#  ['21081',
#   'Brownlee III, Travis',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'March, 2019',
#   'Active'],
#  ['16655',
#   'Brownlee III, Travis',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'February, 2017',
#   'Active'],
#  ['98820',
#   'Brownlee, Samuel',
#   'Mediapolis, IA',
#   'UNITED STATES',
#   'CQE',
#   'June, 2016',
#   'Active'],
#  ['55672',
#   'Brownlee, Samuel',
#   'Mediapolis, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'March, 2019',
#   'Active'],
#  ['9911',
#   'Brunssen, Jared',
#   'Webster City, IA',
#   'UNITED STATES',
#   'CQIA',
#   'December, 2013',
#   'Active'],
#  ['67683',
#   'Bryant, Robert',
#   'Donnellson, IA',
#   'UNITED STATES',
#   'CQA',
#   'October, 2017',
#   'Active'],
#  ['102118',
#   'Bryant, Robert',
#   'Donnellson, IA',
#   'UNITED STATES',
#   'CQE',
#   'June, 2018',
#   'Active'],
#  ['7860',
#   'Buchanan, Barry A.',
#   'Atlantic, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1997',
#   'Active'],
#  ['8923',
#   'Buchanan, Barry A.',
#   'Atlantic, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1994',
#   'Active'],
#  ['4298',
#   'Buchanan, William N.',
#   'Des Moines, IA',
#   'UNITED STATES',
#   'CQI',
#   'March, 1993',
#   'Active'],
#  ['19212',
#   'Buescher, Mel',
#   'Waterloo, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2005',
#   'Active'],
#  ['20300',
#   'Buffington, Sara',
#   'Coralville, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2019',
#   'Active'],
#  ['93',
#   'Buhr, Lori L.',
#   'Bettendorf, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'October, 2001',
#   'Active'],
#  ['897',
#   'Bultsma SR, Karl J.',
#   'Evansdale, IA',
#   'UNITED STATES',
#   'CQIA',
#   'December, 2001',
#   'Active'],
#  ['14698',
#   'Burger, David J.',
#   'Cedar Rapids, IA',
#   'UNITED STATES',
#   'CQIA',
#   'December, 2019',
#   'Active'],
#  ['27129',
#   'Burger, David J.',
#   'Cedar Rapids, IA',
#   'UNITED STATES',
#   'CQA',
#   'December, 2001',
#   'Active'],
#  ['28891',
#   'Burgmeyer, Scott J.',
#   'Norwalk, IA',
#   'UNITED STATES',
#   'CQA',
#   'May, 2003',
#   'Active'],
#  ['7234',
#   'Burgmeyer, Scott J.',
#   'Norwalk, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'March, 2003',
#   'Active'],
#  ['43147',
#   'Burgmeyer, Scott J.',
#   'Norwalk, IA',
#   'UNITED STATES',
#   'CQE',
#   'December, 2001',
#   'Active'],
#  ['1914',
#   'Burgmeyer, Scott J.',
#   'Norwalk, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'March, 2004',
#   'Active'],
#  ['40500',
#   'Burkhart, Kelly M.',
#   'Ames, IA',
#   'UNITED STATES',
#   'CQA',
#   'May, 2010',
#   'Active'],
#  ['3259',
#   'Burkle, Joseph J.',
#   'Cedar Rapids, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1991',
#   'Active'],
#  ['723',
#   'Burlin, Tyler J.',
#   'Middletown, IA',
#   'UNITED STATES',
#   'CCT',
#   'June, 2007',
#   'Active'],
#  ['21643',
#   'Burlin, Tyler J.',
#   'Middletown, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 2009',
#   'Active'],
#  ['19992',
#   'Burrell, Tyler',
#   'Des Moines, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'April, 2019',
#   'Active'],
#  ['18326',
#   'Burrow, Stephen',
#   'Oskaloosa, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 2003',
#   'Active'],
#  ['11950',
#   'Butin, Robert E.',
#   'Garner, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 1996',
#   'Active'],
#  ['6263',
#   'Butin, Robert E.',
#   'Garner, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1995',
#   'Active'],
#  ['10249',
#   'Butville, Scott J.',
#   'Independence, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'December, 2013',
#   'Active'],
#  ['66070',
#   'Buys, Donna L',
#   'Council Bluffs, IA',
#   'UNITED STATES',
#   'CQA',
#   'June, 2016',
#   'Active'],
#  ['23261',
#   'Buys, Donna L',
#   'Council Bluffs, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2014',
#   'Active'],
#  ['5300',
#   'Cahill, Charles E.',
#   'Davenport, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1990',
#   'Active'],
#  ['25254',
#   'Cairy, Michael',
#   'North Liberty, IA',
#   'UNITED STATES',
#   'CQT',
#   'May, 2018',
#   'Active'],
#  ['21138',
#   'Cairy, Michael',
#   'North Liberty, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'May, 2019',
#   'Active'],
#  ['104408',
#   'Cairy, Michael',
#   'North Liberty, IA',
#   'UNITED STATES',
#   'CQE',
#   'February, 2020',
#   'Active'],
#  ['75166',
#   'Cairy, Michael',
#   'North Liberty, IA',
#   'UNITED STATES',
#   'CQI',
#   'November, 2017',
#   'Active'],
#  ['9356',
#   'Calderon, Vanessa',
#   'Des Moines, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2013',
#   'Active'],
#  ['18329',
#   'Caldwell, Tracy Lynn',
#   'Ottumwa, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 2003',
#   'Active'],
#  ['17777',
#   'Calhoun, Taylor',
#   'Cedar Falls, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'October, 2017',
#   'Active'],
#  ['21650',
#   'Calvelage, Dallas S.',
#   'Muscatine, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'November, 2019',
#   'Active'],
#  ['4721',
#   'Cameron, Anna C.',
#   'Grimes, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1993',
#   'Active'],
#  ['3263',
#   'Cameron, Bruce A.',
#   'Grimes, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1991',
#   'Active'],
#  ['67858',
#   'Campbell, Marquise',
#   'Des Moines, IA',
#   'UNITED STATES',
#   'CQA',
#   'October, 2017',
#   'Active'],
#  ['54804',
#   'Campbell, Marquise',
#   'Des Moines, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'November, 2017',
#   'Active'],
#  ['9360',
#   'Campney, Phil',
#   'Urbandale, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2013',
#   'Active'],
#  ['13765',
#   'Canavan-Sorrell, Lois',
#   'Boone, IA',
#   'UNITED STATES',
#   'CQIA',
#   'December, 2018',
#   'Active'],
#  ['8329',
#   'Cao, Ann',
#   'Des Moines, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'December, 2012',
#   'Active'],
#  ['2674',
#   'Carlson, Curtis D.',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CSQE',
#   'June, 2004',
#   'Active'],
#  ['448',
#   'Carlson, Curtis D.',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'May, 2002',
#   'Active'],
#  ['3156',
#   'Carlson, Curtis D.',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CRE',
#   'March, 1992',
#   'Active'],
#  ['24248',
#   'Carlson, Curtis D.',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CQE',
#   'June, 1991',
#   'Active'],
#  ['8516',
#   'Carlson, Dan G.',
#   'Pella, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1998',
#   'Active'],
#  ['10376',
#   'Carlson, Dan G.',
#   'Pella, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1995',
#   'Active'],
#  ['61515',
#   'Carnes, Jason',
#   'Waverly, IA',
#   'UNITED STATES',
#   'CQE',
#   'December, 2013',
#   'Active'],
#  ['17069',
#   'Carnes, Jason',
#   'Waverly, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'March, 2014',
#   'Active'],
#  ['3265',
#   'Carpenter, Kenneth R.',
#   'Cedar Rapids, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1991',
#   'Active'],
#  ['7920',
#   'Carpenter, Kenneth R.',
#   'Cedar Rapids, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1993',
#   'Active'],
#  ['2591',
#   'Carpenter, Veronica L.',
#   'Davenport, IA',
#   'UNITED STATES',
#   'CQIA',
#   'June, 2004',
#   'Active'],
#  ['2846',
#   'Carter, Danielle L.',
#   'Hudson, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2009',
#   'Active'],
#  ['31469',
#   'Case, Rhonda K.',
#   'Iowa City, IA',
#   'UNITED STATES',
#   'CQA',
#   'December, 2004',
#   'Active'],
#  ['3267',
#   'Cavin, Ada K.',
#   'Des Moines, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1991',
#   'Active'],
#  ['7658',
#   'Cecil, Erin',
#   'Davenport, IA',
#   'UNITED STATES',
#   'CQIA',
#   'June, 2010',
#   'Active'],
#  ['8338',
#   'Cerne, Daniel',
#   'Coralville, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'December, 2012',
#   'Active'],
#  ['10266',
#   'Chadwick, Seth W.',
#   'Cedar Falls, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'December, 2013',
#   'Active'],
#  ['11698',
#   'Chapin, Steven L.',
#   'Hampton, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1996',
#   'Active'],
#  ['22725',
#   'Chaudhary, Avinash',
#   'Coralville, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2013',
#   'Active'],
#  ['17631',
#   'Chaudhary, Avinash',
#   'Coralville, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'March, 2016',
#   'Active'],
#  ['12763',
#   'Chaudhary, Avinash',
#   'Coralville, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'December, 2014',
#   'Active'],
#  ['33',
#   'Cheeseman, Brent C.',
#   'Janesville, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2006',
#   'Active'],
#  ['8287',
#   'Chelesvig, Patricia L.',
#   'Webster City, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1993',
#   'Active'],
#  ['6389',
#   'Chintalapati, Venkata Satya N.H',
#   'Bettendorf, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2011',
#   'Active'],
#  ['13529',
#   'Chiugu, Michael N.',
#   'Newton, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2015',
#   'Active'],
#  ['16857',
#   'Chiugu, Michael N.',
#   'Newton, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'October, 2015',
#   'Active'],
#  ['9924',
#   'Christenson, Jamie',
#   'Des Moines, IA',
#   'UNITED STATES',
#   'CQIA',
#   'December, 2013',
#   'Active'],
#  ['1720',
#   'Chugh, Pankaj K',
#   'Asbury, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2008',
#   'Active'],
#  ['2232',
#   'Cibula, Duane A',
#   'Cedar Rapids, IA',
#   'UNITED STATES',
#   'CQPA',
#   'October, 2015',
#   'Active'],
#  ['21131',
#   'Cibula, Duane A',
#   'Cedar Rapids, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 2008',
#   'Active'],
#  ['8271',
#   'Ciecior, Katherine',
#   'North Liberty, IA',
#   'UNITED STATES',
#   'CRE',
#   'March, 2014',
#   'Active'],
#  ['34804',
#   'Clapper, Michael',
#   'Newton, IA',
#   'UNITED STATES',
#   'CRE',
#   'July, 2019',
#   'Active'],
#  ['3532',
#   'Clark, Bette M.',
#   'Ida Grove, IA',
#   'UNITED STATES',
#   'CQIA',
#   'June, 2005',
#   'Active'],
#  ['10290',
#   'Clark, Dustin W.',
#   'Floyd, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'December, 2013',
#   'Active'],
#  ['16337',
#   'Clark, Kara',
#   'Des Moines, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'March, 2015',
#   'Active'],
#  ['14625',
#   'Clarke, Jamie L',
#   'Cedar Falls, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'December, 2015',
#   'Active'],
#  ['5847',
#   'Clausen, Shelley J.',
#   'Stanhope, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 1990',
#   'Active'],
#  ['12284',
#   'Clayberg, Loween J.',
#   'Webster City, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 1996',
#   'Active'],
#  ['12343',
#   'Cleveland, Christine J.',
#   'Charles City, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 1996',
#   'Active'],
#  ['16165',
#   'Clubine, Donald J.',
#   'Reinbeck, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 2000',
#   'Active'],
#  ['5381',
#   'Clubine, Donald J.',
#   'Reinbeck, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1994',
#   'Active'],
#  ['14334',
#   'Clymer, Justin',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CQI',
#   'March, 2014',
#   'Active'],
#  ['23536',
#   'Clymer, Justin',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 2014',
#   'Active'],
#  ['11220',
#   'Clymer, Justin',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CQIA',
#   'June, 2015',
#   'Active'],
#  ['63',
#   'Clymer, Justin',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CSSYB',
#   'March, 2015',
#   'Active'],
#  ['7118',
#   'Coates, Marty D.',
#   'Red Oak, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1992',
#   'Active'],
#  ['20043',
#   'Colbert, Nathaniel P.',
#   'Cedar Falls, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'April, 2019',
#   'Active'],
#  ['692',
#   'Coleman JR, Clarence J.C.',
#   'Waterloo, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'October, 2002',
#   'Active'],
#  ['15111',
#   'Coleman JR, Clarence J.C.',
#   'Waterloo, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'October, 2011',
#   'Active'],
#  ['2988',
#   'Collins, Carolyn',
#   'Slater, IA',
#   'UNITED STATES',
#   'CQT',
#   'April, 1987',
#   'Active'],
#  ['2509',
#   'Collins, Elizabeth A.',
#   'Neveda, IA',
#   'UNITED STATES',
#   'CQT',
#   'April, 1986',
#   'Active'],
#  ['8439',
#   'Comstock, Sherie L.',
#   'Malcom, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 1993',
#   'Active'],
#  ['14323',
#   'Concannon, James D.',
#   'Story City, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1999',
#   'Active'],
#  ['9344',
#   'Concannon, James D.',
#   'Story City, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1999',
#   'Active'],
#  ['18838',
#   'Condon, Jason',
#   'Des Moines, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'March, 2017',
#   'Active'],
#  ['8425',
#   'Conlan, Roger J.',
#   'Clive, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'March, 2009',
#   'Active'],
#  ['13438',
#   'Conover, Aaron',
#   'Holstein, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2015',
#   'Active'],
#  ['8265',
#   'Conte, Michael J.',
#   'Red Oak, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1993',
#   'Active'],
#  ['4055',
#   'Conte, Michael J.',
#   'Red Oak, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1992',
#   'Active'],
#  ['46424',
#   'Conway, Heather J.',
#   'Oakland, IA',
#   'UNITED STATES',
#   'CQA',
#   'December, 2013',
#   'Active'],
#  ['12323',
#   'Cook, Daniel',
#   'Parnell, IA',
#   'UNITED STATES',
#   'CQI',
#   'March, 2006',
#   'Active'],
#  ['6264',
#   'Cook, Terry L.',
#   'Garner, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1995',
#   'Active'],
#  ['13409',
#   'Cook, Terry L.',
#   'Garner, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1998',
#   'Active'],
#  ['35925',
#   'Cooper, Cathy J.',
#   'Leon, IA',
#   'UNITED STATES',
#   'CQA',
#   'June, 2007',
#   'Active'],
#  ['10229',
#   'Cooper, David L.',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'October, 2006',
#   'Active'],
#  ['44684',
#   'Cooper, David L.',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CQE',
#   'May, 2003',
#   'Active'],
#  ['834',
#   'Cooper, David L.',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CBA',
#   'October, 2011',
#   'Active'],
#  ['3594',
#   'Cooper, David L.',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'October, 2005',
#   'Active'],
#  ['21',
#   'Cooper, David L.',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CSQP',
#   'October, 2016',
#   'Active'],
#  ['10938',
#   'Cooper, Richard A.',
#   'Garner, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 2001',
#   'Active'],
#  ['17738',
#   'Cornell, Aaron',
#   'Marion, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2002',
#   'Active'],
#  ['16566',
#   'Cornell, Aaron',
#   'Marion, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'December, 2016',
#   'Active'],
#  ['2995',
#   'Cosgrove, Barbara J.',
#   'Ames, IA',
#   'UNITED STATES',
#   'CQT',
#   'April, 1987',
#   'Active'],
#  ['12160',
#   'Coughlin, Jana K.',
#   'Elliott, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 2005',
#   'Active'],
#  ['3844',
#   'Craig, Marvin D.',
#   'Osceola, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1992',
#   'Active'],
#  ['14251',
#   'Criscuolo, David A.',
#   'Pella, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 1998',
#   'Active'],
#  ['15496',
#   'Criscuolo, David A.',
#   'Pella, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'October, 2014',
#   'Active'],
#  ['19055',
#   'Crocker, Kelli',
#   'Cedar Rapids, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'August, 2018',
#   'Active'],
#  ['11750',
#   'Cromer, Kevin R.',
#   'Riverside, IA',
#   'UNITED STATES',
#   'CQI',
#   'March, 2004',
#   'Active'],
#  ['12084',
#   'Cross, Karen K.',
#   'Webster City, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 1996',
#   'Active'],
#  ['3279',
#   'Cross, Lanie E.',
#   'West Des Moines, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1991',
#   'Active'],
#  ['11362',
#   'Cross, Lanie E.',
#   'West Des Moines, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1996',
#   'Active'],
#  ['1034',
#   'Crouthamel, Scott A.',
#   'Boone, IA',
#   'UNITED STATES',
#   'CQT',
#   'April, 1981',
#   'Active'],
#  ['25139',
#   'Crozier, Christy',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CQT',
#   'January, 2018',
#   'Active'],
#  ['2537',
#   'Crozier, Christy',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CCT',
#   'February, 2019',
#   'Active'],
#  ['2233',
#   'Cruse, Andrew J',
#   'Cedar Rapids, IA',
#   'UNITED STATES',
#   'CQPA',
#   'October, 2015',
#   'Active'],
#  ['11275',
#   'Culberson, Brian K.',
#   'Cedar Falls, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1996',
#   'Active'],
#  ['6265',
#   'Cummings, Steven R.',
#   'Cedar Rapids, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1991',
#   'Active'],
#  ['12397',
#   'Curry, Nancy J.',
#   'Altoona, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'October, 2008',
#   'Active'],
#  ['33041',
#   'Curry, Nancy J.',
#   'Altoona, IA',
#   'UNITED STATES',
#   'CQA',
#   'October, 2005',
#   'Active'],
#  ['8387',
#   'Dale, Kurt A.',
#   'Williamsburg, IA',
#   'UNITED STATES',
#   'CQI',
#   'March, 1998',
#   'Active'],
#  ['28727',
#   'Darley, Daniel W.',
#   'Fort Madison, IA',
#   'UNITED STATES',
#   'CQE',
#   'December, 1992',
#   'Active'],
#  ['12685',
#   'Davis, Adam L.',
#   'North Liberty, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 2007',
#   'Active'],
#  ['5259',
#   'Davis, Bryan L.',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CQIA',
#   'May, 2007',
#   'Active'],
#  ['13770',
#   'Davis, Courtney Mace',
#   'Winfield, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'May, 2010',
#   'Active'],
#  ['2788',
#   'Davis, Donna R.',
#   'Cedar Rapids, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 1986',
#   'Active'],
#  ['13469',
#   'Davis, Douglas E.',
#   'Keokuk, IA',
#   'UNITED STATES',
#   'CQI',
#   'March, 2011',
#   'Active'],
#  ['3282',
#   'Davis, Mark B.',
#   'W. Des Moines, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1991',
#   'Active'],
#  ['9235',
#   'Davis, Sue D.',
#   'Red Oak, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1999',
#   'Active'],
#  ['11597',
#   'Davis, Sue D.',
#   'Red Oak, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1996',
#   'Active'],
#  ['23702',
#   'Davis, Thomas',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 2014',
#   'Active'],
#  ['10460',
#   'Davis, Thomas',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CQIA',
#   'June, 2014',
#   'Active'],
#  ['52793',
#   'Davison, Wendell',
#   'Riverside, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'March, 2015',
#   'Active'],
#  ['97549',
#   'Davison, Wendell',
#   'Riverside, IA',
#   'UNITED STATES',
#   'CQE',
#   'December, 2015',
#   'Active'],
#  ['51945',
#   'Day, James M.',
#   'Johnston, IA',
#   'UNITED STATES',
#   'CQE',
#   'December, 2007',
#   'Active'],
#  ['22535',
#   'Day, James M.',
#   'Johnston, IA',
#   'UNITED STATES',
#   'CQA',
#   'June, 2000',
#   'Active'],
#  ['2593',
#   'De Jong, Laura',
#   'Pella, IA',
#   'UNITED STATES',
#   'CCT',
#   'August, 2019',
#   'Active'],
#  ['25150',
#   'De Jong, Laura',
#   'Pella, IA',
#   'UNITED STATES',
#   'CQT',
#   'January, 2018',
#   'Active'],
#  ['10437',
#   'Deardorff, Gary J.',
#   'Shenandoah, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1995',
#   'Active'],
#  ['11327',
#   'Deardorff, Joe L.',
#   'Shenandoah, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1996',
#   'Active'],
#  ['13242',
#   'Decker, Stephen L.',
#   'Mason City, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 1997',
#   'Active'],
#  ['1475',
#   'Degrange, Melanie',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CQPA',
#   'June, 2013',
#   'Active'],
#  ['13008',
#   'Deibler, Matthew J.',
#   'Garner, IA',
#   'UNITED STATES',
#   'CQI',
#   'March, 2009',
#   'Active'],
#  ['3165',
#   'Deimerly, Douglas D.',
#   'Brooklyn, IA',
#   'UNITED STATES',
#   'CQI',
#   'March, 1991',
#   'Active'],
#  ['7556',
#   'Deimerly, Douglas D.',
#   'Brooklyn, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 1992',
#   'Active'],
#  ['14326',
#   'DeJong, James A.',
#   'Pella, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1999',
#   'Active'],
#  ['1181',
#   'Delong, Gary A.',
#   'Urbandale, IA',
#   'UNITED STATES',
#   'CFSQA',
#   'March, 2013',
#   'Active'],
#  ['35001',
#   'Delong, Gary A.',
#   'Urbandale, IA',
#   'UNITED STATES',
#   'CQA',
#   'December, 2006',
#   'Active'],
#  ['16920',
#   'Denner, Corey M.',
#   'Hiawatha, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2001',
#   'Active'],
#  ['6099',
#   'Denny, Steve',
#   'Kanawha, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'March, 2007',
#   'Active'],
#  ['23545',
#   'Depuew, David',
#   'Belmond, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 2014',
#   'Active'],
#  ['8037',
#   'Deranleau, Robert C.',
#   'Creston, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1993',
#   'Active'],
#  ['9825',
#   'DeRonde, Kathryn L.',
#   'Knoxville, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 1994',
#   'Active'],
#  ['44809',
#   'Deruiter, Craig L.',
#   'Centerville, IA',
#   'UNITED STATES',
#   'CQE',
#   'June, 2003',
#   'Active'],
#  ['15881',
#   'Deshazer, Rochelle',
#   'Davenport, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'October, 2014',
#   'Active'],
#  ['1112',
#   'Deskin, Krista S.',
#   'Waukee, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'March, 2003',
#   'Active'],
#  ['7555',
#   'Diam, Akaff Saeed',
#   'Cedar Falls, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'October, 2008',
#   'Active'],
#  ['50531',
#   'Diam, Akaff Saeed',
#   'Cedar Falls, IA',
#   'UNITED STATES',
#   'CQE',
#   'December, 2006',
#   'Active'],
#  ['14184',
#   'Dibble, Andrew A.',
#   'Decorah, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'December, 2015',
#   'Active'],
#  ['617',
#   'Dickenson, Greg L.',
#   'Pella, IA',
#   'UNITED STATES',
#   'CQIA',
#   'June, 2001',
#   'Active'],
#  ['5345',
#   'Diggelmann, Linda K.',
#   'Iowa City, IA',
#   'UNITED STATES',
#   'CQIA',
#   'June, 2007',
#   'Active'],
#  ['7126',
#   'Dill, Shanna',
#   'North Liberty, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'March, 2008',
#   'Active'],
#  ['14878',
#   'Doerscher, Christopher',
#   'Davenport, IA',
#   'UNITED STATES',
#   'CQIA',
#   'June, 2020',
#   'Active'],
#  ['19237',
#   'Dokter, Barry A.',
#   'Sioux Center, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2005',
#   'Active'],
#  ['62541',
#   'Dolan, Chris',
#   'Keokuk, IA',
#   'UNITED STATES',
#   'CQE',
#   'June, 2014',
#   'Active'],
#  ['64831',
#   'Dolan, Chris',
#   'Keokuk, IA',
#   'UNITED STATES',
#   'CQA',
#   'December, 2015',
#   'Active'],
#  ['17552',
#   'Dolan, Chris',
#   'Keokuk, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'October, 2014',
#   'Active'],
#  ['1018',
#   'Dostal, Robert G.',
#   'Iowa City, IA',
#   'UNITED STATES',
#   'CQT',
#   'April, 1981',
#   'Active'],
#  ['29503',
#   'Dotseth, Robert Eric',
#   'Burlington, IA',
#   'UNITED STATES',
#   'CQE',
#   'June, 1993',
#   'Active'],
#  ['20788',
#   'Dougherty, Krista',
#   'Denver, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'October, 2019',
#   'Active'],
#  ['8995',
#   'Downes, Michael J.',
#   'Davenport, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'December, 2012',
#   'Active'],
#  ['4430',
#   'Downes, Michael J.',
#   'Davenport, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1989',
#   'Active'],
#  ['14701',
#   'Drew, Brian F.',
#   'Decorah, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'December, 2015',
#   'Active'],
#  ['13314',
#   'Duke, Erica',
#   'Waukee, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2015',
#   'Active'],
#  ['13507',
#   'Duncan, Tom',
#   'Holstein, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2015',
#   'Active'],
#  ['4435',
#   'Dunn, William J.',
#   'Davenport, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1989',
#   'Active'],
#  ['17977',
#   'Dunphy-Anderson, Lucy M.',
#   'Duncombe, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 2002',
#   'Active'],
#  ['1264',
#   'Dunphy-Anderson, Lucy M.',
#   'Duncombe, IA',
#   'UNITED STATES',
#   'CQIA',
#   'June, 2002',
#   'Active'],
#  ['3294',
#   'Dye, Dan Edwin',
#   'Central City, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1991',
#   'Active'],
#  ['18624',
#   'Dye, Victoria M.',
#   'Pella, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2004',
#   'Active'],
#  ['14480',
#   'Dykshoorn, Susan K.',
#   'Ames, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1999',
#   'Active'],
#  ['15394',
#   'Eamkajornsiri, Sutee',
#   'Ames, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'May, 2014',
#   'Active'],
#  ['60738',
#   'Eamkajornsiri, Sutee',
#   'Ames, IA',
#   'UNITED STATES',
#   'CQE',
#   'June, 2013',
#   'Active'],
#  ['7536',
#   'Eamkajornsiri, Sutee',
#   'Ames, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2012',
#   'Active'],
#  ['5902',
#   'Ebelsheiser, Jeremy',
#   'Waterloo, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2011',
#   'Active'],
#  ['1054',
#   'Eberhart, Joseph M.',
#   'Delmar, IA',
#   'UNITED STATES',
#   'CQI',
#   'April, 1987',
#   'Active'],
#  ['7158',
#   'Eberhart, Joseph M.',
#   'Delmar, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1992',
#   'Active'],
#  ['57320',
#   'Eck, Daudi',
#   'Bettendorf, IA',
#   'UNITED STATES',
#   'CQE',
#   'June, 2011',
#   'Active'],
#  ['15320',
#   'Eck, Daudi',
#   'Bettendorf, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'March, 2012',
#   'Active'],
#  ['39598',
#   'Eck, Daudi',
#   'Bettendorf, IA',
#   'UNITED STATES',
#   'CQA',
#   'June, 2009',
#   'Active'],
#  ['7365',
#   'Eck, Daudi',
#   'Bettendorf, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'May, 2012',
#   'Active'],
#  ['7699',
#   'Eggers, Scott J.',
#   'Clinton, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 1992',
#   'Active'],
#  ['941',
#   'Eibey, Geary D.',
#   'Janesville, IA',
#   'UNITED STATES',
#   'CQIA',
#   'December, 2001',
#   'Active'],
#  ['8465',
#   'Eilers, David',
#   'Des Moines, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'March, 2009',
#   'Active'],
#  ['11648',
#   'Eilers, Kevin A.',
#   'Blue Grass, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1996',
#   'Active'],
#  ['54312',
#   'Eilers, Mel A.',
#   'Des Moines, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'January, 2017',
#   'Active'],
#  ['52933',
#   'El Hachimi Alaoui SR, Moulay Abdelhafid',
#   'Des Moines, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'October, 2015',
#   'Active'],
#  ['29071',
#   'Ellert-Beck, Daniel Philip',
#   'Dubuque, IA',
#   'UNITED STATES',
#   'CQA',
#   'June, 2003',
#   'Active'],
#  ['45425',
#   'Ellert-Beck, Daniel Philip',
#   'Dubuque, IA',
#   'UNITED STATES',
#   'CQE',
#   'December, 2003',
#   'Active'],
#  ['61985',
#   'Elliott, Deborah A.',
#   'Le Claire, IA',
#   'UNITED STATES',
#   'CQE',
#   'December, 2013',
#   'Active'],
#  ['7949',
#   'Elliott, Deborah A.',
#   'Le Claire, IA',
#   'UNITED STATES',
#   'CRE',
#   'March, 2013',
#   'Active'],
#  ['70177',
#   'Ellis, Stephanie',
#   'Ottumwa, IA',
#   'UNITED STATES',
#   'CQA',
#   'June, 2019',
#   'Active'],
#  ['20530',
#   'Ellis, Stephanie',
#   'Ottumwa, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'August, 2019',
#   'Active'],
#  ['896',
#   'Ellis, Stephanie',
#   'Ottumwa, IA',
#   'UNITED STATES',
#   'CSQP',
#   'January, 2020',
#   'Active'],
#  ['5943',
#   'Elsbury, Joel A.',
#   'Mason City, IA',
#   'UNITED STATES',
#   'CQI',
#   'March, 1995',
#   'Active'],
#  ['101914',
#   'Elwer, John',
#   'Iowa City, IA',
#   'UNITED STATES',
#   'CQE',
#   'June, 2018',
#   'Active'],
#  ['22277',
#   'Enderson, Todd A',
#   'Milford, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2012',
#   'Active'],
#  ['9550',
#   'Erickson, Dale M.',
#   'Humboldt, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1994',
#   'Active'],
#  ['1768',
#   'Ertl, Brad',
#   'Dyersville, IA',
#   'UNITED STATES',
#   'CSSYB',
#   'July, 2019',
#   'Active'],
#  ['11862',
#   'Escritt, Kenneth E.',
#   'Macedonia, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 1996',
#   'Active'],
#  ['23282',
#   'Essmann, Michael',
#   'West Des Moines, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2014',
#   'Active'],
#  ['63372',
#   'Evans, Curtis R.',
#   'Bettendorf, IA',
#   'UNITED STATES',
#   'CQA',
#   'March, 2015',
#   'Active'],
#  ['16072',
#   'Evans, Curtis R.',
#   'Bettendorf, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'January, 2013',
#   'Active'],
#  ['12012',
#   'Evans, Dennis J.',
#   'Columbus City, IA',
#   'UNITED STATES',
#   'CQI',
#   'March, 2005',
#   'Active'],
#  ['19899',
#   'Evans, Dennis J.',
#   'Columbus City, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2006',
#   'Active'],
#  ['8207',
#   'Even, Ryan J.',
#   'Jesup, IA',
#   'UNITED STATES',
#   'CQIA',
#   'June, 2011',
#   'Active'],
#  ['17110',
#   'Even, Ryan J.',
#   'Jesup, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'March, 2014',
#   'Active'],
#  ['55877',
#   'Even, Ryan J.',
#   'Jesup, IA',
#   'UNITED STATES',
#   'CQE',
#   'June, 2010',
#   'Active'],
#  ['5348',
#   'Even, Ryan J.',
#   'Jesup, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'December, 2010',
#   'Active'],
#  ['1220',
#   'Everett, David',
#   'Indianola, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'May, 2003',
#   'Active'],
#  ['9441',
#   'Faler, William',
#   'Marion, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2013',
#   'Active'],
#  ['19902',
#   'Fank, Nicholas D.',
#   'Kelley, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2006',
#   'Active'],
#  ['4446',
#   'Farmer, Jerry L.',
#   'Wheatland, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1989',
#   'Active'],
#  ['3159',
#   'Farrell, Suzan R.',
#   'Waucoma, IA',
#   'UNITED STATES',
#   'CQIA',
#   'December, 2004',
#   'Active'],
#  ['12013',
#   'Fay, Mick W.',
#   'Red Oak, IA',
#   'UNITED STATES',
#   'CQI',
#   'March, 2005',
#   'Active'],
#  ['48562',
#   'Fedirko, Erika L.',
#   'Johnston, IA',
#   'UNITED STATES',
#   'CQA',
#   'December, 2014',
#   'Active'],
#  ['14128',
#   'Fellmer, Victoria',
#   'Hampton, IA',
#   'UNITED STATES',
#   'CQIA',
#   'June, 2019',
#   'Active'],
#  ['4613',
#   'Fennelly, Ann P.',
#   'Davenport, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1989',
#   'Active'],
#  ['11637',
#   'Fenton, Jill L.',
#   'Britt, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1996',
#   'Active'],
#  ['9558',
#   'Fergus, Scott D.',
#   'Dubuque, IA',
#   'UNITED STATES',
#   'CQIA',
#   'June, 2013',
#   'Active'],
#  ['15430',
#   'Fernando, Shehan A.',
#   'Cedar Falls, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2016',
#   'Active'],
#  ['6372',
#   'Ferriss, Shirley I.',
#   'Marshalltown, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1995',
#   'Active'],
#  ['7012',
#   'Field, John E.',
#   'Floyd, IA',
#   'UNITED STATES',
#   'CQI',
#   'March, 1996',
#   'Active'],
#  ['14692',
#   'Finch, Gabe',
#   'Marion, IA',
#   'UNITED STATES',
#   'CQIA',
#   'December, 2019',
#   'Active'],
#  ['9404',
#   'Fischels, Charles M.',
#   'Webster City, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1994',
#   'Active'],
#  ['9318',
#   'Fischer, Joe H.',
#   'Rolfe, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1994',
#   'Active'],
#  ['14400',
#   'Fischer, Mary M.',
#   'Rolfe, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1999',
#   'Active'],
#  ['3600',
#   'Fischer, Mary M.',
#   'Rolfe, IA',
#   'UNITED STATES',
#   'CQI',
#   'March, 1992',
#   'Active'],
#  ['21683',
#   'Fitzgerald, Robert',
#   'Middletown, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2010',
#   'Active'],
#  ['17909',
#   'Flaherty, Patrick',
#   'Urbandale, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'March, 2016',
#   'Active'],
#  ['13478',
#   'Flores, Ricardo',
#   'Keokuk, IA',
#   'UNITED STATES',
#   'CQI',
# ...
#   'Coralville, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'October, 2018',
#   'Active'],
#  ['11784',
#   'Lavely, John W.',
#   'Wellman, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2014',
#   'Active'],
#  ['9994',
#   'Lavely, John W.',
#   'Wellman, IA',
#   'UNITED STATES',
#   'CQE',
#   'December, 1983',
#   'Active'],
#  ['23340',
#   'Lawman, Lucas',
#   'Ames, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2014',
#   'Active'],
#  ['5106',
#   'Lawson, John P.',
#   'Cedar Falls, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'October, 2006',
#   'Active'],
#  ['2665',
#   'Leathers, Jamie L.',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CQPA',
#   'February, 2017',
#   'Active'],
#  ['6664',
#   'Leathers, Jamie L.',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CQIA',
#   'December, 2008',
#   'Active'],
#  ['2206',
#   'Lee, Keun M.',
#   'Cedar Rapids, IA',
#   'UNITED STATES',
#   'CQPA',
#   'June, 2015',
#   'Active'],
#  ['5453',
#   'Lee, Kevin R.',
#   'Eldridge, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1990',
#   'Active'],
#  ['11716',
#   'Lee, Vanessa',
#   'Dixon, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2014',
#   'Active'],
#  ['441',
#   'Leforge, Mark H.',
#   'Fairfax, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'December, 2006',
#   'Active'],
#  ['60872',
#   'Legendre, Kenneth W',
#   'Clinton, IA',
#   'UNITED STATES',
#   'CQE',
#   'June, 2013',
#   'Active'],
#  ['40710',
#   'Legendre, Kenneth W',
#   'Clinton, IA',
#   'UNITED STATES',
#   'CQA',
#   'June, 2010',
#   'Active'],
#  ['19311',
#   'Lentz, Jeff A.',
#   'Waterloo, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2005',
#   'Active'],
#  ['20110',
#   'Leonard, Josh',
#   'North Liberty, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'May, 2018',
#   'Active'],
#  ['55550',
#   'Leonard, Josh',
#   'North Liberty, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'November, 2018',
#   'Active'],
#  ['99572',
#   'Leonard, Josh',
#   'North Liberty, IA',
#   'UNITED STATES',
#   'CQE',
#   'December, 2016',
#   'Active'],
#  ['17018',
#   'Leonard, Josh',
#   'North Liberty, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'April, 2017',
#   'Active'],
#  ['68831',
#   'Leonovicz, Stacey',
#   'Council Bluffs, IA',
#   'UNITED STATES',
#   'CQA',
#   'June, 2018',
#   'Active'],
#  ['19312',
#   'Leraas, David A',
#   'LeMars, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2005',
#   'Active'],
#  ['19010',
#   'Lewis, Brian Joseph',
#   'Dubuque, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 2004',
#   'Active'],
#  ['1239',
#   'Lewis, Brian Joseph',
#   'Dubuque, IA',
#   'UNITED STATES',
#   'CQPA',
#   'June, 2012',
#   'Active'],
#  ['8286',
#   'Lewis, Brian Joseph',
#   'Dubuque, IA',
#   'UNITED STATES',
#   'CQIA',
#   'June, 2011',
#   'Active'],
#  ['47729',
#   'Lewis, Brian Joseph',
#   'Dubuque, IA',
#   'UNITED STATES',
#   'CQA',
#   'June, 2014',
#   'Active'],
#  ['53329',
#   'Lewis, Brian Joseph',
#   'Dubuque, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'October, 2015',
#   'Active'],
#  ['58234',
#   'Lewis, Brian Joseph',
#   'Dubuque, IA',
#   'UNITED STATES',
#   'CQE',
#   'December, 2011',
#   'Active'],
#  ['2030',
#   'Lewis, Brian Joseph',
#   'Dubuque, IA',
#   'UNITED STATES',
#   'CCT',
#   'June, 2015',
#   'Active'],
#  ['9608',
#   'Lewis, Brian Joseph',
#   'Dubuque, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2013',
#   'Active'],
#  ['4054',
#   'Lewis, John R.',
#   'Red Oak, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1992',
#   'Active'],
#  ['8264',
#   'Lewis, John R.',
#   'Red Oak, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1993',
#   'Active'],
#  ['5640',
#   'Lewis, Steven R.',
#   'Garner, IA',
#   'UNITED STATES',
#   'CQI',
#   'March, 1995',
#   'Active'],
#  ['10673',
#   'Lewis, Timothy',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CQIA',
#   'December, 2014',
#   'Active'],
#  ['15492',
#   'Lex, Brian',
#   'Asbury, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'October, 2014',
#   'Active'],
#  ['8135',
#   'Licko, Tim L.',
#   'Mediapolis, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1993',
#   'Active'],
#  ['23343',
#   'Ligouri, James M.',
#   'Story City, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2014',
#   'Active'],
#  ['8530',
#   'Liljedahl, Sandra F.',
#   'Lake Mills, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1998',
#   'Active'],
#  ['13596',
#   'Limbrick, Quasadia',
#   'Waterloo, IA',
#   'UNITED STATES',
#   'CQIA',
#   'October, 2018',
#   'Active'],
#  ['21297',
#   'Limbrick, Quasadia',
#   'Waterloo, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'February, 2020',
#   'Active'],
#  ['5275',
#   'Linde, Michael S',
#   'Pella, IA',
#   'UNITED STATES',
#   'CRE',
#   'March, 2002',
#   'Active'],
#  ['6861',
#   'Linde, Michael S',
#   'Pella, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 1991',
#   'Active'],
#  ['37191',
#   'Linde, Michael S',
#   'Pella, IA',
#   'UNITED STATES',
#   'CQE',
#   'June, 1997',
#   'Active'],
#  ['12283',
#   'Linn, Barbara J.',
#   'Webster City, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 1996',
#   'Active'],
#  ['11237',
#   'Litterer, Russell D.',
#   'Mason City, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1996',
#   'Active'],
#  ['14640',
#   'Livin, Andrew',
#   'Cedar Rapids, IA',
#   'UNITED STATES',
#   'CQI',
#   'March, 2015',
#   'Active'],
#  ['10030',
#   'Loh, Ruey',
#   'Amana, IA',
#   'UNITED STATES',
#   'CQIA',
#   'December, 2013',
#   'Active'],
#  ['8278',
#   'Lohmann, John R.',
#   'Burlington, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1993',
#   'Active'],
#  ['1245',
#   'Londono, Oscar',
#   'MUSCATINE, IA',
#   'UNITED STATES',
#   'CSSYB',
#   'September, 2018',
#   'Active'],
#  ['10712',
#   'Loney, Krisha',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CQIA',
#   'December, 2014',
#   'Active'],
#  ['9627',
#   'Long, James N.',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2013',
#   'Active'],
#  ['3379',
#   'Long, Robert T.',
#   'Cedar Rapids, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1991',
#   'Active'],
#  ['11364',
#   'Longhurst, George L.',
#   'Muscatine, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 2002',
#   'Active'],
#  ['18055',
#   'Longhurst, George L.',
#   'Muscatine, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2003',
#   'Active'],
#  ['18426',
#   'Lorenzen, Christopher T.',
#   'Davenport, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'October, 2016',
#   'Active'],
#  ['22338',
#   'Loring, Gary D',
#   'Aurelia, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2012',
#   'Active'],
#  ['101924',
#   'Lotero, Kevin',
#   'Dubuque, IA',
#   'UNITED STATES',
#   'CQE',
#   'June, 2018',
#   'Active'],
#  ['24288',
#   'Lott, Chad E',
#   'Burlington, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 2015',
#   'Active'],
#  ['102203',
#   'Loughry, Tessa',
#   'Cedar Falls, IA',
#   'UNITED STATES',
#   'CQE',
#   'August, 2018',
#   'Active'],
#  ['64330',
#   'Loussaert, Michael E',
#   'Eldridge, IA',
#   'UNITED STATES',
#   'CQA',
#   'July, 2015',
#   'Active'],
#  ['10464',
#   'Lowe, Bryan',
#   'Pleasant Hill, IA',
#   'UNITED STATES',
#   'CQIA',
#   'June, 2014',
#   'Active'],
#  ['5812',
#   'Lower, Donald E.',
#   'Williamsburg, IA',
#   'UNITED STATES',
#   'CQI',
#   'March, 1995',
#   'Active'],
#  ['17778',
#   'Lubben, Taylor',
#   'Cedar Falls, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'October, 2017',
#   'Active'],
#  ['8922',
#   'Lucy, Jeremy J.',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CQIA',
#   'June, 2012',
#   'Active'],
#  ['377',
#   'Ludeman, Trisha Renee',
#   'Cedar Falls, IA',
#   'UNITED STATES',
#   'CSQP',
#   'March, 2018',
#   'Active'],
#  ['61714',
#   'Ludwick, Noel R.',
#   'Nevada, IA',
#   'UNITED STATES',
#   'CQE',
#   'December, 2013',
#   'Active'],
#  ['20512',
#   'Lueth, Michael',
#   'Cedar Falls, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'August, 2019',
#   'Active'],
#  ['13782',
#   'Lunday, Chris',
#   'Ames, IA',
#   'UNITED STATES',
#   'CQIA',
#   'December, 2018',
#   'Active'],
#  ['7523',
#   'Luskey, Amy J.',
#   'Maquoketa, IA',
#   'UNITED STATES',
#   'CQIA',
#   'June, 2010',
#   'Active'],
#  ['561',
#   'Luskey, Amy J.',
#   'Maquoketa, IA',
#   'UNITED STATES',
#   'CQPA',
#   'June, 2009',
#   'Active'],
#  ['11622',
#   'Lusson, Rachel J.',
#   'Evansdale, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2014',
#   'Active'],
#  ['512',
#   'Mackey, Connie L.',
#   'Waterloo, IA',
#   'UNITED STATES',
#   'CQIA',
#   'June, 2001',
#   'Active'],
#  ['20181',
#   'Mackey, Connie L.',
#   'Waterloo, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 2006',
#   'Active'],
#  ['63671',
#   'Mackey, Connie L.',
#   'Waterloo, IA',
#   'UNITED STATES',
#   'CQE',
#   'December, 2014',
#   'Active'],
#  ['39213',
#   'Mackey, Connie L.',
#   'Waterloo, IA',
#   'UNITED STATES',
#   'CQA',
#   'June, 2009',
#   'Active'],
#  ['53158',
#   'Mackey, Connie L.',
#   'Waterloo, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'October, 2015',
#   'Active'],
#  ['3773',
#   'Macleod, Donald E.',
#   'Ankeny, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'December, 2009',
#   'Active'],
#  ['12728',
#   'Macnider, Matthew',
#   'Cedar Rapids, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'December, 2014',
#   'Active'],
#  ['11718',
#   'Maddix, Kaytlin',
#   'Sac City, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2014',
#   'Active'],
#  ['9430',
#   'Magsamen, Kenneth L.',
#   'West Union, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1994',
#   'Active'],
#  ['14155',
#   'Mahlkuch, Harlan R.',
#   'Bettendorf, IA',
#   'UNITED STATES',
#   'CQIA',
#   'June, 2019',
#   'Active'],
#  ['75456',
#   'Mahlkuch, Harlan R.',
#   'Bettendorf, IA',
#   'UNITED STATES',
#   'CQI',
#   'February, 2019',
#   'Active'],
#  ['1388',
#   'Manfull, Bradley',
#   'West Des Moines, IA',
#   'UNITED STATES',
#   'CQPA',
#   'December, 2012',
#   'Active'],
#  ['75431',
#   'Mangine, Michael',
#   'Waverly, IA',
#   'UNITED STATES',
#   'CQI',
#   'January, 2019',
#   'Active'],
#  ['1609',
#   'Marker, Michele M.',
#   'Cedar Rapids, IA',
#   'UNITED STATES',
#   'CQPA',
#   'December, 2013',
#   'Active'],
#  ['6868',
#   'Marnin, Todd A.',
#   'Belmond, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 1991',
#   'Active'],
#  ['12945',
#   'Marnin, Todd A.',
#   'Belmond, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'October, 2009',
#   'Active'],
#  ['2152',
#   'Maronn, Dennis R.',
#   'Davenport, IA',
#   'UNITED STATES',
#   'CQT',
#   'April, 1985',
#   'Active'],
#  ['11462',
#   'Marshall, L. Darlene',
#   'Monroe, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1996',
#   'Active'],
#  ['11257',
#   'Martin JR, Lafe',
#   'Fort Madison, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1996',
#   'Active'],
#  ['4529',
#   'Martin, Bernie A.',
#   'West Union, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1993',
#   'Active'],
#  ['12657',
#   'Martin, Charles',
#   'Cedar Rapids, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'December, 2014',
#   'Active'],
#  ['109',
#   'Martin, Dennis L.',
#   'Davenport, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1984',
#   'Active'],
#  ['2149',
#   'Martin, Dennis L.',
#   'Davenport, IA',
#   'UNITED STATES',
#   'CQT',
#   'April, 1985',
#   'Active'],
#  ['23618',
#   'Martin, Jeanette',
#   'Essex, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 2014',
#   'Active'],
#  ['11327',
#   'Martin, Kara L.',
#   'Marion, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2014',
#   'Active'],
#  ['15411',
#   'Martin, Thomas J.',
#   'Marion, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'May, 2014',
#   'Active'],
#  ['10906',
#   'Marx, Laurie T.',
#   'DE Witt, IA',
#   'UNITED STATES',
#   'CQIA',
#   'December, 2014',
#   'Active'],
#  ['13541',
#   'Mary, Brad S.',
#   'Forest City, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1998',
#   'Active'],
#  ['8527',
#   'Mason, Joel L.',
#   'Cedar Falls, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'March, 2009',
#   'Active'],
#  ['3691',
#   'Mason, Rozann M.',
#   'Waterloo, IA',
#   'UNITED STATES',
#   'CQT',
#   'April, 1988',
#   'Active'],
#  ['681',
#   'Mason, Rozann M.',
#   'Waterloo, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'October, 2002',
#   'Active'],
#  ['2287',
#   'Mason, Rozann M.',
#   'Waterloo, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1989',
#   'Active'],
#  ['98763',
#   'Mason, Thomas W.',
#   'Cedar Falls, IA',
#   'UNITED STATES',
#   'CQE',
#   'June, 2016',
#   'Active'],
#  ['13352',
#   'Mason, Thomas W.',
#   'Cedar Falls, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2015',
#   'Active'],
#  ['53537',
#   'Masood, Suhaib',
#   'Mason City, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'March, 2016',
#   'Active'],
#  ['8928',
#   'Masten, Trevor',
#   'Urbandale, IA',
#   'UNITED STATES',
#   'CQIA',
#   'June, 2012',
#   'Active'],
#  ['23351',
#   'Masterson, Aaron',
#   'Waterloo, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2014',
#   'Active'],
#  ['22013',
#   'Mattly, Dana',
#   'Pella, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2011',
#   'Active'],
#  ['2144',
#   'Mayes, Trulie',
#   'Fort Madison, IA',
#   'UNITED STATES',
#   'CSSYB',
#   'March, 2020',
#   'Active'],
#  ['6410',
#   'McCallister, Daniel J.',
#   'Williamsburg, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1995',
#   'Active'],
#  ['54302',
#   'Mccargar, Steve',
#   'Carroll, IA',
#   'UNITED STATES',
#   'CQE',
#   'June, 2009',
#   'Active'],
#  ['19032',
#   'McCarthy, Monica D.',
#   'Des Moines, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 2004',
#   'Active'],
#  ['1793',
#   'Mccolm, Mark L.',
#   'Readlyn, IA',
#   'UNITED STATES',
#   'CQPA',
#   'June, 2014',
#   'Active'],
#  ['5030',
#   'Mccolm, Mark L.',
#   'Readlyn, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'December, 2010',
#   'Active'],
#  ['20557',
#   'McCombs, Mary Theresa',
#   'Eddyville, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2007',
#   'Active'],
#  ['13622',
#   'McCombs, Mary Theresa',
#   'Eddyville, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 2011',
#   'Active'],
#  ['8531',
#   'McCormick, Paula L.',
#   'Lake Mills, IA',
#   'UNITED STATES',
#   'CQI',
#   'October, 1998',
#   'Active'],
#  ['9536',
#   'McCubbin, Jeffrey M.',
#   'Forest City, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1994',
#   'Active'],
#  ['75458',
#   'McCubbin, Mitch N.',
#   'Davenport, IA',
#   'UNITED STATES',
#   'CQI',
#   'February, 2019',
#   'Active'],
#  ['992',
#   'Mcculley, James N.',
#   'Muscatine, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'June, 2007',
#   'Active'],
#  ['3838',
#   'McCullough, Brian E.',
#   'Hudson, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'October, 2005',
#   'Active'],
#  ['12109',
#   'McCullough, Brian E.',
#   'Hudson, IA',
#   'UNITED STATES',
#   'CMQ/OE',
#   'October, 2008',
#   'Active'],
#  ['8757',
#   'McCullough, Brian E.',
#   'Hudson, IA',
#   'UNITED STATES',
#   'CQIA',
#   'December, 2011',
#   'Active'],
#  ['20813',
#   'McDaniel, Ebony',
#   'Waterloo, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'October, 2019',
#   'Active'],
#  ['17891',
#   'McDermott, Ryan',
#   'Des Moines, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'March, 2016',
#   'Active'],
#  ['12384',
#   'McDonald, Brian',
#   'Marion, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'December, 2014',
#   'Active'],
#  ['5069',
#   'McDonald, Norman D.',
#   'Marion, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 1989',
#   'Active'],
#  ['5',
#   'McDougall, Randall C.',
#   'Cedar Falls, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'April, 2006',
#   'Active'],
#  ['2231',
#   'McGlashing, Tim J',
#   'Cedar Rapids, IA',
#   'UNITED STATES',
#   'CQPA',
#   'October, 2015',
#   'Active'],
#  ['2677',
#   'McGlynn, Becky Ann',
#   'Dubuque, IA',
#   'UNITED STATES',
#   'CQPA',
#   'April, 2017',
#   'Active'],
#  ['11100',
#   'McGlynn, Becky Ann',
#   'Dubuque, IA',
#   'UNITED STATES',
#   'CQIA',
#   'June, 2015',
#   'Active'],
#  ['546',
#   'McGlynn, Becky Ann',
#   'Dubuque, IA',
#   'UNITED STATES',
#   'CSSYB',
#   'January, 2017',
#   'Active'],
#  ['23356',
#   'McGovern, Michael J.',
#   'Hiawatha, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2014',
#   'Active'],
#  ['6873',
#   'McLaughlin, Sherri L.',
#   'Belmond, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 1991',
#   'Active'],
#  ['101618',
#   'McLean, Stephanie',
#   'Cedar Rapids, IA',
#   'UNITED STATES',
#   'CQE',
#   'February, 2018',
#   'Active'],
#  ['66603',
#   'McMahon, Mollie',
#   'Johnston, IA',
#   'UNITED STATES',
#   'CQA',
#   'December, 2016',
#   'Active'],
#  ['6928',
#   'Mcmahon, Shannon L.',
#   'Waverly, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'December, 2011',
#   'Active'],
#  ['14989',
#   'McMichael, Kevin P.',
#   'Mason City, IA',
#   'UNITED STATES',
#   'CQT',
#   'October, 1999',
#   'Active'],
#  ['13817',
#   'Mcsweeney, Matthew',
#   'Cedar Falls, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'March, 2013',
#   'Active'],
#  ['19801',
#   'McVietty, Anthony',
#   'Princeton, IA',
#   'UNITED STATES',
#   'CSSGB',
#   'February, 2019',
#   'Active'],
#  ['24417',
#   'McVietty, Anthony',
#   'Princeton, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2016',
#   'Active'],
#  ['625',
#   'Meier, Jason D.',
#   'Waterloo, IA',
#   'UNITED STATES',
#   'CQIA',
#   'June, 2001',
#   'Active'],
#  ['18716',
#   'Meinders, Alan J.',
#   'Pella, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 2004',
#   'Active'],
#  ['18486',
#   'Meiners, Todd C.',
#   'Des Moines, IA',
#   'UNITED STATES',
#   'CSSBB',
#   'October, 2016',
#   'Active'],
#  ['9583',
#   'Meints, Terry L.',
#   'Klemme, IA',
#   'UNITED STATES',
#   'CQT',
#   'March, 1994',
#   'Active'],
#  ...]

# %%
df = pd.DataFrame(certs[1], columns = ['ASQ ID', 'Name', 'City', 'Country', 'Credential', 'Date Earned', 'Status'])
df
# Out:
#      ASQ ID                    Name             City        Country  \
# 0      9601         Abele, Grant D.       Garner, IA  UNITED STATES
# 1       516         Abele, Grant D.       Garner, IA  UNITED STATES
# 2     20318       Abodeely, Paul D.       Lisbon, IA  UNITED STATES
# 3      7036         Adams, David A.       Marion, IA  UNITED STATES
# 4      3529        Adrian, Edwin M.   West Union, IA  UNITED STATES
# ...     ...                     ...              ...            ...
# 1601    841              Zheng, Zhi  Cedar Falls, IA  UNITED STATES
# 1602  69465              Zhou, Ning    Urbandale, IA  UNITED STATES
# 1603  56278              Zhou, Ning    Urbandale, IA  UNITED STATES
# 1604   2986  Ziegenmeyer, Daniel E.    Montezuma, IA  UNITED STATES
# 1605   7212         Zuniga, Jose M.     Waterloo, IA  UNITED STATES
#
#      Credential     Date Earned  Status
# 0           CQI     March, 2000  Active
# 1          CQIA      June, 2001  Active
# 2           CQT     March, 2007  Active
# 3           CQT     March, 1992  Active
# 4           CQI     March, 1992  Active
# ...         ...             ...     ...
# 1601       CQPA  December, 2010  Active
# 1602        CQA  December, 2018  Active
# 1603     CMQ/OE   January, 2020  Active
# 1604        CQI     March, 1991  Active
# 1605      CSSGB  December, 2011  Active
#
# [1606 rows x 7 columns]

# %%
df.to_csv('../asq.csv', sep=',', index=False)
