# %% [markdown]
# # Webscraping dynamic page content

# %% [markdown]
# ### My husband mentioned needing to get information from ASQ (American Society for Quality) about newly certified members. ASQ's site provides some search options, but not as specific as he needed, and he would've needed to copy/paste dozens of pages of search results into a spreadsheet in order to further filter responses. I offered to find a webscraping option for him. My thanks to Damien Martin and this helpful post: https://kiwidamien.github.io/using-api-calls-via-the-network-panel.html for instructions about determining the correct url to access search results.
#
# ### Takeaways from this:
#
# ## 1. In previous projects, I had struggled with how to webscrape pages that required user input (search fields, buttons, etc.). This gave me a great opportunity to learn something new and use it in a way that helped save time and effort and decrease manual input.
#
# ## 2.  Ultimately, I found similar functionality through Excel, which is more widely used by my husband's team, and thus easier for them to incorporate, so this process won't be implemented for now.
#
# ## 3. There will often be multiple options for achieving results. Determining which one best fits a team's skills and needs is a critical step.
#
# ## 4. This was a quick project I did while in the middle of a larger data science project. I hesitated to share it at first, because it only took me a few hours and didn't seem impactful enough to be worthwhile, but EVERY project has the potential to both increase my knowledge and experience as well as possibly being helpful to others.

# %%
import json
import requests
import pandas as pd

# %%
url = 'https://asq.org/cert/asq/VerificationPager.aspx?page=0&size=2000&Certification=&Country=US&State=IA&Province=&Name='

# Make the same request that Javascript makes
r = requests.get(url)

# %%
#Verifying the correct info was collected
print(r.text)
# Out:
# [1606,[["9601", "Abele, Grant D.", "Garner, IA", "UNITED STATES", "CQI", "March, 2000", "Active"],["516", "Abele, Grant D.", "Garner, IA", "UNITED STATES", "CQIA", "June, 2001", "Active"],["20318", "Abodeely, Paul D.", "Lisbon, IA", "UNITED STATES", "CQT", "March, 2007", "Active"],["7036", "Adams, David A.", "Marion, IA", "UNITED STATES", "CQT", "March, 1992", "Active"],["3529", "Adrian, Edwin M.", "West Union, IA", "UNITED STATES", "CQI", "March, 1992", "Active"],["21845", "Agarwal, Nikhil", "Davenport, IA", "UNITED STATES", "CQT", "October, 2010", "Active"],["2448", "Ahmed, Ovais", "Bettendorf, IA", "UNITED STATES", "CSSBB", "October, 2004", "Active"],["36869", "Ahmed, Ovais", "Bettendorf, IA", "UNITED STATES", "CQE", "June, 1997", "Active"],["15906", "Ahmed, Ovais", "Bettendorf, IA", "UNITED STATES", "CQA", "December, 1996", "Active"],["65338", "Alagappan Thangavel, Saravanan", "Coralville, IA", "UNITED STATES", "CQA", "May, 2016", "Active"],["98838", "Alagappan Thangavel, Saravanan", "Coralville, IA", "UNITED STATES", "CQE", "June, 2016", "Active"],["17755", "Alagappan Thangavel, Saravanan", "Coralville, IA", "UNITED STATES", "CSSGB", "October, 2017", "Active"],["54359", "Alagappan Thangavel, Saravanan", "Coralville, IA", "UNITED STATES", "CMQ/OE", "January, 2017", "Active"],["15212", "Albers, Laurie A.", "Clarion, IA", "UNITED STATES", "CQT", "October, 1999", "Active"],["11153", "Albert, Richard D.", "Eldon, IA", "UNITED STATES", "CQT", "March, 1996", "Active"],["44523", "Albert, Richard D.", "Eldon, IA", "UNITED STATES", "CQE", "December, 2002", "Active"],["11184", "Alcorn, Larry W.", "Winterset, IA", "UNITED STATES", "CQT", "March, 1996", "Active"],["3531", "Allen, Charles J.", "Danville, IA", "UNITED STATES", "CQI", "March, 1992", "Active"],["14670", "Allen, Matthew D.", "Solon, IA", "UNITED STATES", "CMQ/OE", "April, 2011", "Active"],["57975", "Allen, Matthew D.", "Solon, IA", "UNITED STATES", "CQE", "December, 2011", "Active"],["5745", "Allen, Matthew D.", "Solon, IA", "UNITED STATES", "CSSGB", "June, 2011", "Active"],["7359", "Allen, Matthew D.", "Solon, IA", "UNITED STATES", "CRE", "October, 2011", "Active"],["41285", "Allen, Matthew D.", "Solon, IA", "UNITED STATES", "CQA", "December, 2010", "Active"],["24505", "Allen, Thomas E.", "Missouri Valley, IA", "UNITED STATES", "CQT", "March, 2016", "Active"],["16227", "Allen, Tracy L.", "Hornick, IA", "UNITED STATES", "CQT", "October, 2000", "Active"],["7041", "Allison, Carol A.", "Waterloo, IA", "UNITED STATES", "CQT", "March, 1992", "Active"],["20223", "Allman, Allyson", "North Liberty, IA", "UNITED STATES", "CSSGB", "June, 2019", "Active"],["15001", "Almon, Guy W.", "Pella, IA", "UNITED STATES", "CQT", "October, 1999", "Active"],["12345", "Anderberg, Jay S.", "Webster City, IA", "UNITED STATES", "CQT", "October, 1996", "Active"],["2787", "Anderson, Collin W.", "Cedar Falls, IA", "UNITED STATES", "CSSGB", "June, 2009", "Active"],["22240", "Anderson, Curtis A.", "Spencer, IA", "UNITED STATES", "CQT", "March, 2012", "Active"],["12315", "Anderson, Ed R.", "Webster City, IA", "UNITED STATES", "CQT", "October, 1996", "Active"],["23234", "Anderson, Jay C", "Council Bluffs, IA", "UNITED STATES", "CQT", "March, 2014", "Active"],["48602", "Anderson, Jay C", "Council Bluffs, IA", "UNITED STATES", "CQA", "December, 2014", "Active"],["15929", "Anderson, Michael A.", "Ames, IA", "UNITED STATES", "CQT", "March, 2000", "Active"],["22994", "Anderson, Scott A.", "Spencer, IA", "UNITED STATES", "CQT", "October, 2013", "Active"],["8836", "Anderson, Vicki L.", "Sheffield, IA", "UNITED STATES", "CQT", "October, 1993", "Active"],["11653", "Andreasen, Deanna L.", "Forest City, IA", "UNITED STATES", "CQT", "March, 1996", "Active"],["12595", "Andrews, Kyle", "Cedar Rapids, IA", "UNITED STATES", "CSSGB", "December, 2014", "Active"],["4928", "Angstrom, Charles A.", "Fort Dodge, IA", "UNITED STATES", "CQI", "March, 1994", "Active"],["2247", "Anschutz, Wayne F.", "Pella, IA", "UNITED STATES", "CMQ ...

# %%
#Organizing and formatting the information so it can be put in a dataframe and saved as .csv file
certs = []
certs.extend(r.json())

# %%
#View a sample of the information so I can correctly assign dataframe column names
certs[1][1]
# Out:
# ['516',
#  'Abele, Grant D.',
#  'Garner, IA',
#  'UNITED STATES',
#  'CQIA',
#  'June, 2001',
#  'Active']

# %%
df = pd.DataFrame(certs[1], columns = ['ASQ ID', 'Name', 'City', 'Country', 'Credential', 'Date Earned', 'Status'])
df
# Out:
#      ASQ ID                    Name             City        Country  \
# 0      9601         Abele, Grant D.       Garner, IA  UNITED STATES
# 1       516         Abele, Grant D.       Garner, IA  UNITED STATES
# 2     20318       Abodeely, Paul D.       Lisbon, IA  UNITED STATES
# 3      7036         Adams, David A.       Marion, IA  UNITED STATES
# 4      3529        Adrian, Edwin M.   West Union, IA  UNITED STATES
# ...     ...                     ...              ...            ...
# 1601    841              Zheng, Zhi  Cedar Falls, IA  UNITED STATES
# 1602  69465              Zhou, Ning    Urbandale, IA  UNITED STATES
# 1603  56278              Zhou, Ning    Urbandale, IA  UNITED STATES
# 1604   2986  Ziegenmeyer, Daniel E.    Montezuma, IA  UNITED STATES
# 1605   7212         Zuniga, Jose M.     Waterloo, IA  UNITED STATES
#
#      Credential     Date Earned  Status
# 0           CQI     March, 2000  Active
# 1          CQIA      June, 2001  Active
# 2           CQT     March, 2007  Active
# 3           CQT     March, 1992  Active
# 4           CQI     March, 1992  Active
# ...         ...             ...     ...
# 1601       CQPA  December, 2010  Active
# 1602        CQA  December, 2018  Active
# 1603     CMQ/OE   January, 2020  Active
# 1604        CQI     March, 1991  Active
# 1605      CSSGB  December, 2011  Active
#
# [1606 rows x 7 columns]

# %%
df.to_csv('../asq.csv', sep=',', index=False)
